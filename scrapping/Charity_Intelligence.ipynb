# %% [markdown]
# # Scraping Charity Intelligence Canada

# %% [markdown]
# ## Bibliotecas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Paso 1: Investigar la página
#
# Use las DevTools para saber cómo buscar en el código los links que me interesaban, además de notar que las páginas con los links eran la misma dirección y sólo se moodificaba el último número de 20 en 20.

# %% [markdown]
# ![devtools](./images/devtools_01.png "Click derecho inspect")

# %% [markdown]
# ## Paso 2: Solicitud a Chat GPT
# Después pregunte a ChatGPT (prompt engineering)

# %% [markdown]
# ![chatGPT](./images/prompt_01.png "pregunta a chatGPT")
# ![chatGPT](./images/prompt_02.png "pregunta a chatGPT")
# ![chatGPT](./images/prompt_03.png "pregunta a chatGPT")

# %% [markdown]
# ## Paso 3. Recopilar links individuales de cada caridad

# %%
base_url = "https://www.charityintelligence.ca/charity-profiles/a-z-charity-listing?start="
start_points = range(0, 860, 20)  # generates start points from 0 to 840

all_links = []

for start in start_points:
    url = f"{base_url}{start}"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        charity_links = soup.find_all('a', class_='title lnk')
        for link in charity_links:
            href = link.get('href')
            if href:
                all_links.append(f"https://www.charityintelligence.ca{href}")
    else:
        print(f"Failed to retrieve page with start={start}")

# Print all collected links
for link in all_links:
    print(link)

# Save the links to a file
with open("./data/charity_intelligence_links.txt", "w") as f:
    for link in all_links:
        f.write(link + "\n")
# Out:
# https://www.charityintelligence.ca/charity-details/856-360kids-support-services
# https://www.charityintelligence.ca/charity-details/967-a-better-world-canada
# https://www.charityintelligence.ca/charity-details/309-acadia-university
# https://www.charityintelligence.ca/charity-details/154-acclaim-health
# https://www.charityintelligence.ca/charity-details/1084-action-canada-for-sexual-health-rights
# https://www.charityintelligence.ca/charity-details/542-adra-canada
# https://www.charityintelligence.ca/charity-details/1-aga-khan-foundation-canada
# https://www.charityintelligence.ca/charity-details/908-against-malaria-foundation-canada
# https://www.charityintelligence.ca/charity-details/652-agence-ometz
# https://www.charityintelligence.ca/charity-details/110-agincourt-community-services-association
# https://www.charityintelligence.ca/charity-details/926-ahmadiyya-muslim-jama-at-canada
# https://www.charityintelligence.ca/charity-details/692-alberta-adolescent-recovery-centre
# https://www.charityintelligence.ca/charity-details/911-alberta-animal-rescue-crew-society-aarcs
# https://www.charityintelligence.ca/charity-details/3-alberta-cancer-foundation
# https://www.charityintelligence.ca/charity-details/5-alberta-children-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/270-alberta-conservation-association
# https://www.charityintelligence.ca/charity-details/271-alberta-ecotrust-foundation
# https://www.charityintelligence.ca/charity-details/337-alberta-lung-association
# https://www.charityintelligence.ca/charity-details/910-alberta-wilderness-association
# https://www.charityintelligence.ca/charity-details/233-alice-house
# https://www.charityintelligence.ca/charity-details/930-alliance-canada
# https://www.charityintelligence.ca/charity-details/1085-ally-global-foundation
# https://www.charityintelligence.ca/charity-details/891-alpha-house-society
# https://www.charityintelligence.ca/charity-details/578-als-bc
# https://www.charityintelligence.ca/charity-details/610-als-society-of-canada
# https://www.charityintelligence.ca/charity-details/837-alzheimer-society-of-alberta-nwt
# https://www.charityintelligence.ca/charity-details/303-alzheimer-society-of-bc
# https://www.charityintelligence.ca/charity-details/192-alzheimer-society-of-canada
# https://www.charityintelligence.ca/charity-details/343-alzheimer-society-of-ontario
# https://www.charityintelligence.ca/charity-details/835-alzheimer-society-of-toronto
# https://www.charityintelligence.ca/charity-details/155-amici-children-s-camp-charity
# https://www.charityintelligence.ca/charity-details/170-amnesty-international-canadian-section
# https://www.charityintelligence.ca/charity-details/995-amnesty-international-french-canadian-section
# https://www.charityintelligence.ca/charity-details/1049-amref-health-africa-in-canada
# https://www.charityintelligence.ca/charity-details/895-archdiocese-of-toronto
# https://www.charityintelligence.ca/charity-details/511-art-gallery-of-alberta
# https://www.charityintelligence.ca/charity-details/6-art-gallery-of-ontario
# https://www.charityintelligence.ca/charity-details/768-arthritis-research-canada
# https://www.charityintelligence.ca/charity-details/182-arthritis-society-canada
# https://www.charityintelligence.ca/charity-details/488-aspen-family-and-community-network-society
# https://www.charityintelligence.ca/charity-details/468-assiniboine-park-conservancy
# https://www.charityintelligence.ca/charity-details/272-atlantic-salmon-federation
# https://www.charityintelligence.ca/charity-details/232-aunt-leah-s
# https://www.charityintelligence.ca/charity-details/996-autism-ontario
# https://www.charityintelligence.ca/charity-details/474-autism-speaks-canada
# https://www.charityintelligence.ca/charity-details/899-b-nai-levy-foundation
# https://www.charityintelligence.ca/charity-details/1067-backpack-buddies
# https://www.charityintelligence.ca/charity-details/351-banff-centre
# https://www.charityintelligence.ca/charity-details/157-barbra-schlifer-commemorative-clinic
# https://www.charityintelligence.ca/charity-details/7-baycrest-centre-foundation
# https://www.charityintelligence.ca/charity-details/87-bc-cancer-foundation
# https://www.charityintelligence.ca/charity-details/8-bc-children-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/10-bc-spca
# https://www.charityintelligence.ca/charity-details/845-belleville-general-hospital-foundation
# https://www.charityintelligence.ca/charity-details/870-beth-oloth-charitable-organization
# https://www.charityintelligence.ca/charity-details/647-bgc-canada
# https://www.charityintelligence.ca/charity-details/700-bgc-winnipeg
# https://www.charityintelligence.ca/charity-details/860-big-brothers-big-sisters-of-calgary-and-area
# https://www.charityintelligence.ca/charity-details/219-big-brothers-big-sisters-of-canada
# https://www.charityintelligence.ca/charity-details/127-big-brothers-big-sisters-toronto
# https://www.charityintelligence.ca/charity-details/859-big-brothers-of-greater-vancouver
# https://www.charityintelligence.ca/charity-details/1020-big-sisters-of-bc-lower-mainland
# https://www.charityintelligence.ca/charity-details/801-birds-canada
# https://www.charityintelligence.ca/charity-details/1048-bissell-centre
# https://www.charityintelligence.ca/charity-details/1086-black-health-alliance
# https://www.charityintelligence.ca/charity-details/961-bladder-cancer-canada
# https://www.charityintelligence.ca/charity-details/772-blue-sea-foundation
# https://www.charityintelligence.ca/charity-details/541-boys-girls-clubs-big-brothers-big-sisters-of-edmonton-area
# https://www.charityintelligence.ca/charity-details/861-boys-and-girls-club-of-ottawa
# https://www.charityintelligence.ca/charity-details/843-boys-and-girls-clubs-of-calgary
# https://www.charityintelligence.ca/charity-details/858-boys-and-girls-clubs-of-south-coast-bc
# https://www.charityintelligence.ca/charity-details/906-brain-canada
# https://www.charityintelligence.ca/charity-details/615-brain-tumour-foundation-of-canada
# https://www.charityintelligence.ca/charity-details/106-brands-for-canada
# https://www.charityintelligence.ca/charity-details/115-breakfast-club-of-canada
# https://www.charityintelligence.ca/charity-details/194-breast-cancer-canada
# https://www.charityintelligence.ca/charity-details/363-british-columbia-lung-foundation
# https://www.charityintelligence.ca/charity-details/1065-brown-bagging-for-calgary-s-kids
# https://www.charityintelligence.ca/charity-details/273-bruce-trail-conservancy
# https://www.charityintelligence.ca/charity-details/1071-burnaby-hospital-foundation
# https://www.charityintelligence.ca/charity-details/601-cabbagetown-community-arts-centre
# https://www.charityintelligence.ca/charity-details/173-calgary-catholic-immigration-society
# https://www.charityintelligence.ca/charity-details/480-calgary-drop-in
# https://www.charityintelligence.ca/charity-details/866-calgary-flames-foundation
# https://www.charityintelligence.ca/charity-details/11-calgary-food-bank
# https://www.charityintelligence.ca/charity-details/19-calgary-health-foundation
# https://www.charityintelligence.ca/charity-details/175-calgary-homeless-foundation
# https://www.charityintelligence.ca/charity-details/212-calgary-humane-society
# https://www.charityintelligence.ca/charity-details/529-calgary-philharmonic-orchestra
# https://www.charityintelligence.ca/charity-details/849-calgary-public-library-foundation
# https://www.charityintelligence.ca/charity-details/623-calgary-stampede-foundation
# https://www.charityintelligence.ca/charity-details/243-cambridge-food-bank
# https://www.charityintelligence.ca/charity-details/1037-camfed-canada
# https://www.charityintelligence.ca/charity-details/593-camp-quality
# https://www.charityintelligence.ca/charity-details/990-campfire-circle
# https://www.charityintelligence.ca/charity-details/792-canada-company
# https://www.charityintelligence.ca/charity-details/1004-canada-gives
# https://www.charityintelligence.ca/charity-details/1110-canada-ukraine-foundation
# https://www.charityintelligence.ca/charity-details/902-canadahelps
# https://www.charityintelligence.ca/charity-details/370-canadian-bible-society
# https://www.charityintelligence.ca/charity-details/857-canadian-blood-services
# https://www.charityintelligence.ca/charity-details/242-canadian-cancer-society
# https://www.charityintelligence.ca/charity-details/1087-canadian-centre-for-policy-alternatives
# https://www.charityintelligence.ca/charity-details/1095-canadian-civil-liberties-association
# https://www.charityintelligence.ca/charity-details/841-canadian-constitution-foundation
# https://www.charityintelligence.ca/charity-details/963-canadian-council-of-churches
# https://www.charityintelligence.ca/charity-details/476-canadian-council-of-the-blind
# https://www.charityintelligence.ca/charity-details/1009-canadian-down-syndrome-society
# https://www.charityintelligence.ca/charity-details/73-canadian-feed-the-children
# https://www.charityintelligence.ca/charity-details/624-canadian-food-for-children
# https://www.charityintelligence.ca/charity-details/620-canadian-foodgrains-bank
# https://www.charityintelligence.ca/charity-details/824-canadian-foundation-for-aids-research
# https://www.charityintelligence.ca/charity-details/912-canadian-friends-of-tel-aviv-university
# https://www.charityintelligence.ca/charity-details/713-canadian-guide-dogs-for-the-blind
# https://www.charityintelligence.ca/charity-details/345-canadian-hard-of-hearing-association-newfoundland-and-labrador
# https://www.charityintelligence.ca/charity-details/743-canadian-hearing-services
# https://www.charityintelligence.ca/charity-details/745-canadian-institute-for-advanced-research
# https://www.charityintelligence.ca/charity-details/478-canadian-liver-foundation
# https://www.charityintelligence.ca/charity-details/177-canadian-lung-association
# https://www.charityintelligence.ca/charity-details/510-canadian-lutheran-world-relief
# https://www.charityintelligence.ca/charity-details/505-canadian-mental-health-association
# https://www.charityintelligence.ca/charity-details/959-canadian-national-christian-foundation
# https://www.charityintelligence.ca/charity-details/70-canadian-national-institute-for-the-blind
# https://www.charityintelligence.ca/charity-details/569-canadian-olympic-foundation
# https://www.charityintelligence.ca/charity-details/833-canadian-opera-company
# https://www.charityintelligence.ca/charity-details/274-canadian-parks-and-wilderness-society
# https://www.charityintelligence.ca/charity-details/415-canadian-physicians-for-aid-and-relief
# https://www.charityintelligence.ca/charity-details/71-canadian-red-cross
# https://www.charityintelligence.ca/charity-details/207-canadian-stage
# https://www.charityintelligence.ca/charity-details/636-canadian-tire-jumpstart
# https://www.charityintelligence.ca/charity-details/85-canadian-wildlife-federation
# https://www.charityintelligence.ca/charity-details/377-canadian-women-for-women-in-afghanistan
# https://www.charityintelligence.ca/charity-details/299-canadian-women-s-foundation
# https://www.charityintelligence.ca/charity-details/72-cancer-research-society
# https://www.charityintelligence.ca/charity-details/469-cancercare-manitoba-foundation
# https://www.charityintelligence.ca/charity-details/417-canuck-place-children-s-hospice
# https://www.charityintelligence.ca/charity-details/532-canucks-for-kids-fund
# https://www.charityintelligence.ca/charity-details/314-cape-breton-regional-hospital-foundation
# https://www.charityintelligence.ca/charity-details/582-cape-breton-university
# https://www.charityintelligence.ca/charity-details/183-care-canada
# https://www.charityintelligence.ca/charity-details/1039-carleton-university
# https://www.charityintelligence.ca/charity-details/888-casey-house
# https://www.charityintelligence.ca/charity-details/787-cause-canada
# https://www.charityintelligence.ca/charity-details/711-cd-howe-institute
# https://www.charityintelligence.ca/charity-details/971-cedars-cancer-foundation
# https://www.charityintelligence.ca/charity-details/29-centraide-of-greater-montreal-united-way-montreal
# https://www.charityintelligence.ca/charity-details/423-centraide-outaouais
# https://www.charityintelligence.ca/charity-details/531-centraide-quebec-chaudiere-appalaches-et-bas-saint-laurent
# https://www.charityintelligence.ca/charity-details/953-central-okanagan-food-bank
# https://www.charityintelligence.ca/charity-details/600-centre-for-addiction-and-mental-health-foundation
# https://www.charityintelligence.ca/charity-details/688-centre-for-affordable-water-and-sanitation-technology
# https://www.charityintelligence.ca/charity-details/932-centre-street-church
# https://www.charityintelligence.ca/charity-details/630-chabad-lubavitch-youth-organization
# https://www.charityintelligence.ca/charity-details/14-chalice-canada
# https://www.charityintelligence.ca/charity-details/261-charity-intelligence
# https://www.charityintelligence.ca/charity-details/1106-charity-tzedakah-montreal
# https://www.charityintelligence.ca/charity-details/514-chasdei-tovim-meoros
# https://www.charityintelligence.ca/charity-details/255-child-development-institute
# https://www.charityintelligence.ca/charity-details/266-child-haven-international
# https://www.charityintelligence.ca/charity-details/599-childhood-cancer-canada
# https://www.charityintelligence.ca/charity-details/76-children-believe
# https://www.charityintelligence.ca/charity-details/496-children-s-aid-foundation-of-canada
# https://www.charityintelligence.ca/charity-details/662-children-s-book-bank
# https://www.charityintelligence.ca/charity-details/162-children-s-cottage-society
# https://www.charityintelligence.ca/charity-details/457-children-s-health-foundation
# https://www.charityintelligence.ca/charity-details/495-children-s-hospital-foundation-of-manitoba
# https://www.charityintelligence.ca/charity-details/264-children-s-hospital-of-eastern-ontario-foundation
# https://www.charityintelligence.ca/charity-details/915-children-s-joy-foundation
# https://www.charityintelligence.ca/charity-details/75-children-s-wish-foundation-of-canada
# https://www.charityintelligence.ca/charity-details/216-choices-for-youth
# https://www.charityintelligence.ca/charity-details/486-chu-dumont-foundation
# https://www.charityintelligence.ca/charity-details/398-chu-sainte-justine-foundation
# https://www.charityintelligence.ca/charity-details/917-church-of-jesus-christ-of-latter-day-saints-in-canada
# https://www.charityintelligence.ca/charity-details/900-church-of-virgin-mary-and-st-athanasius
# https://www.charityintelligence.ca/charity-details/26-chus-foundation
# https://www.charityintelligence.ca/charity-details/983-citizens-foundation-canada
# https://www.charityintelligence.ca/charity-details/217-citykidz
# https://www.charityintelligence.ca/charity-details/808-cknw-kids-fund
# https://www.charityintelligence.ca/charity-details/411-ckua-radio-foundation
# https://www.charityintelligence.ca/charity-details/1077-cnewa-canada
# https://www.charityintelligence.ca/charity-details/455-coast-to-coast-against-cancer-foundation
# https://www.charityintelligence.ca/charity-details/581-code
# https://www.charityintelligence.ca/charity-details/665-colon-cancer-canada
# https://www.charityintelligence.ca/charity-details/693-colorectal-cancer-canada
# https://www.charityintelligence.ca/charity-details/235-community-care-of-st-catharines-and-thorold
# https://www.charityintelligence.ca/charity-details/354-community-living-toronto
# https://www.charityintelligence.ca/charity-details/596-community-music-schools-of-toronto
# https://www.charityintelligence.ca/charity-details/77-compassion-canada
# https://www.charityintelligence.ca/charity-details/863-conam-charitable-foundation
# https://www.charityintelligence.ca/charity-details/479-confederation-centre-of-the-arts
# https://www.charityintelligence.ca/charity-details/847-covenant-foundation
# https://www.charityintelligence.ca/charity-details/78-covenant-house-toronto
# https://www.charityintelligence.ca/charity-details/215-covenant-house-vancouver
# https://www.charityintelligence.ca/charity-details/259-crohn-s-and-colitis
# https://www.charityintelligence.ca/charity-details/79-crossroads-christian-communications
# https://www.charityintelligence.ca/charity-details/404-cups-calgary-society
# https://www.charityintelligence.ca/charity-details/209-cuso-international
# https://www.charityintelligence.ca/charity-details/80-cystic-fibrosis-canada
# https://www.charityintelligence.ca/charity-details/605-daily-bread-food-bank
# https://www.charityintelligence.ca/charity-details/428-dalhousie-medical-research-foundation
# https://www.charityintelligence.ca/charity-details/1033-dalhousie-university
# https://www.charityintelligence.ca/charity-details/810-dalit-freedom-network-canada
# https://www.charityintelligence.ca/charity-details/383-dans-la-rue
# https://www.charityintelligence.ca/charity-details/661-david-foster-foundation
# https://www.charityintelligence.ca/charity-details/247-david-suzuki-foundation
# https://www.charityintelligence.ca/charity-details/268-development-and-peace
# https://www.charityintelligence.ca/charity-details/69-diabetes-canada
# https://www.charityintelligence.ca/charity-details/230-discovery-house
# https://www.charityintelligence.ca/charity-details/341-distress-centre-calgary
# https://www.charityintelligence.ca/charity-details/164-distress-centres-of-greater-toronto
# https://www.charityintelligence.ca/charity-details/114-dixon-hall-neighbourhood-services
# https://www.charityintelligence.ca/charity-details/81-doctors-without-borders
# https://www.charityintelligence.ca/charity-details/1089-dollar-a-day-foundation
# https://www.charityintelligence.ca/charity-details/987-dorothy-ley-hospice
# https://www.charityintelligence.ca/charity-details/800-downtown-mission-of-windsor
# https://www.charityintelligence.ca/charity-details/571-dr-h-bliss-murphy-cancer-care-foundation
# https://www.charityintelligence.ca/charity-details/512-dreams-take-flight
# https://www.charityintelligence.ca/charity-details/12-ducks-unlimited-canada
# https://www.charityintelligence.ca/charity-details/458-dying-with-dignity-canada
# https://www.charityintelligence.ca/charity-details/794-earth-rangers-foundation
# https://www.charityintelligence.ca/charity-details/165-east-york-learning-experience
# https://www.charityintelligence.ca/charity-details/717-easter-seals-alberta
# https://www.charityintelligence.ca/charity-details/788-easter-seals-british-columbia-yukon
# https://www.charityintelligence.ca/charity-details/656-easter-seals-canada
# https://www.charityintelligence.ca/charity-details/380-easter-seals-ontario
# https://www.charityintelligence.ca/charity-details/275-ecojustice
# https://www.charityintelligence.ca/charity-details/276-ecotrust-canada
# https://www.charityintelligence.ca/charity-details/226-eden-food-for-change
# https://www.charityintelligence.ca/charity-details/520-edmonton-humane-society
# https://www.charityintelligence.ca/charity-details/463-edmonton-oilers-community-foundation
# https://www.charityintelligence.ca/charity-details/166-edmonton-s-food-bank
# https://www.charityintelligence.ca/charity-details/185-effect-hope
# https://www.charityintelligence.ca/charity-details/1091-egale-canada
# https://www.charityintelligence.ca/charity-details/171-elizabeth-fry-society-of-calgary
# https://www.charityintelligence.ca/charity-details/659-emily-s-house-philip-aziz-centre-for-hospice-care
# https://www.charityintelligence.ca/charity-details/608-engineers-without-borders
# https://www.charityintelligence.ca/charity-details/277-environmental-defence-canada
# https://www.charityintelligence.ca/charity-details/390-epic-society
# https://www.charityintelligence.ca/charity-details/646-erdo
# https://www.charityintelligence.ca/charity-details/1015-ernestine-s-women-s-shelter
# https://www.charityintelligence.ca/charity-details/278-escarpment-biosphere-conservancy
# https://www.charityintelligence.ca/charity-details/822-ethiopiaid-canada
# https://www.charityintelligence.ca/charity-details/158-eva-s-initiatives
# https://www.charityintelligence.ca/charity-details/160-evangel-hall-mission
# https://www.charityintelligence.ca/charity-details/279-evergreen
# https://www.charityintelligence.ca/charity-details/777-farley-foundation
# https://www.charityintelligence.ca/charity-details/399-farm-radio-international
# https://www.charityintelligence.ca/charity-details/587-fear-is-not-love-society
# https://www.charityintelligence.ca/charity-details/90-federation-cja
# https://www.charityintelligence.ca/charity-details/304-feed-nova-scotia
# https://www.charityintelligence.ca/charity-details/444-feed-ontario
# https://www.charityintelligence.ca/charity-details/269-fighting-blindness-canada
# https://www.charityintelligence.ca/charity-details/616-finca-canada
# https://www.charityintelligence.ca/charity-details/975-first-alliance-church
# https://www.charityintelligence.ca/charity-details/821-first-book-canada
# https://www.charityintelligence.ca/charity-details/1018-first-nations-child-family-caring-society-of-canada
# https://www.charityintelligence.ca/charity-details/844-focus-humanitarian-assistance
# https://www.charityintelligence.ca/charity-details/563-focus-on-the-family-canada
# https://www.charityintelligence.ca/charity-details/723-fondation-24h-tremblant
# https://www.charityintelligence.ca/charity-details/551-fondation-charles-bruneau
# https://www.charityintelligence.ca/charity-details/543-fondation-chu-de-quebec
# https://www.charityintelligence.ca/charity-details/333-fondation-de-l-hopital-maisonneuve-rosemont
# https://www.charityintelligence.ca/charity-details/548-fondation-de-la-recherche-pediatrique
# https://www.charityintelligence.ca/charity-details/1021-fondation-desjardins
# https://www.charityintelligence.ca/charity-details/361-fondation-du-chum-fondation-du-centre-hospitalier-de-l-universite-de-montreal
# https://www.charityintelligence.ca/charity-details/1012-fondation-hotel-dieu-de-levis
# https://www.charityintelligence.ca/charity-details/583-fondation-mira
# https://www.charityintelligence.ca/charity-details/625-fondation-papillon
# https://www.charityintelligence.ca/charity-details/540-fondation-quebecoise-du-cancer
# https://www.charityintelligence.ca/charity-details/626-food-banks-canada
# https://www.charityintelligence.ca/charity-details/147-food-banks-mississauga
# https://www.charityintelligence.ca/charity-details/1072-food-banks-of-quebec
# https://www.charityintelligence.ca/charity-details/633-food-depot-alimentaire
# https://www.charityintelligence.ca/charity-details/201-food-for-life-canada
# https://www.charityintelligence.ca/charity-details/347-food-for-the-hungry-fh-canada
# https://www.charityintelligence.ca/charity-details/972-food-for-the-poor-canada
# https://www.charityintelligence.ca/charity-details/238-foodshare
# https://www.charityintelligence.ca/charity-details/672-fora-network-for-change
# https://www.charityintelligence.ca/charity-details/253-fraser-institute
# https://www.charityintelligence.ca/charity-details/204-fred-victor
# https://www.charityintelligence.ca/charity-details/153-fresh-start-recovery-centre
# https://www.charityintelligence.ca/charity-details/424-friends-of-the-canadian-museum-for-human-rights
# https://www.charityintelligence.ca/charity-details/373-friends-of-the-moncton-hospital-foundation
# https://www.charityintelligence.ca/charity-details/460-fung-loy-kok-institute-of-taoism
# https://www.charityintelligence.ca/charity-details/765-furniture-bank
# https://www.charityintelligence.ca/charity-details/809-future-possibilities-for-kids
# https://www.charityintelligence.ca/charity-details/516-gates-of-mercy
# https://www.charityintelligence.ca/charity-details/544-gatineau-health-foundation
# https://www.charityintelligence.ca/charity-details/757-george-brown-college-foundation
# https://www.charityintelligence.ca/charity-details/594-george-hull-centre-for-children-and-families
# https://www.charityintelligence.ca/charity-details/1104-georgian-bay-forever
# https://www.charityintelligence.ca/charity-details/280-georgian-bay-land-trust
# https://www.charityintelligence.ca/charity-details/371-gfa-world
# https://www.charityintelligence.ca/charity-details/783-girl-guides-of-canada
# https://www.charityintelligence.ca/charity-details/924-girls-e-mentorship-innovation
# https://www.charityintelligence.ca/charity-details/167-glenbow-museum
# https://www.charityintelligence.ca/charity-details/964-global-aid-network
# https://www.charityintelligence.ca/charity-details/346-globalmedic
# https://www.charityintelligence.ca/charity-details/553-go-le-grand-defi-inc
# https://www.charityintelligence.ca/charity-details/722-good-shepherd-centre-hamilton
# https://www.charityintelligence.ca/charity-details/632-good-shepherd-ministries
# https://www.charityintelligence.ca/charity-details/473-goodwill-industries-of-toronto
# https://www.charityintelligence.ca/charity-details/1061-gord-downie-and-chanie-wenjack-fund
# https://www.charityintelligence.ca/charity-details/784-grand-river-hospital-foundation
# https://www.charityintelligence.ca/charity-details/927-great-commission-foundation
# https://www.charityintelligence.ca/charity-details/433-greater-vancouver-food-bank-society
# https://www.charityintelligence.ca/charity-details/559-grocery-foundation
# https://www.charityintelligence.ca/charity-details/389-habitat-for-humanity-canada
# https://www.charityintelligence.ca/charity-details/721-habitat-for-humanity-edmonton
# https://www.charityintelligence.ca/charity-details/1022-habitat-for-humanity-greater-vancouver
# https://www.charityintelligence.ca/charity-details/446-habitat-for-humanity-gta
# https://www.charityintelligence.ca/charity-details/1075-habitat-for-humanity-halton-mississauga
# https://www.charityintelligence.ca/charity-details/359-habitat-for-humanity-manitoba
# https://www.charityintelligence.ca/charity-details/832-habitat-for-humanity-niagara
# https://www.charityintelligence.ca/charity-details/873-habitat-for-humanity-saskatchewan
# https://www.charityintelligence.ca/charity-details/429-habitat-for-humanity-southern-alberta
# https://www.charityintelligence.ca/charity-details/459-halton-learning-foundation
# https://www.charityintelligence.ca/charity-details/558-hamilton-food-share
# https://www.charityintelligence.ca/charity-details/339-hamilton-health-sciences-foundation
# https://www.charityintelligence.ca/charity-details/720-harvest-house-ministries-of-ottawa
# https://www.charityintelligence.ca/charity-details/471-harvest-manitoba
# https://www.charityintelligence.ca/charity-details/484-health-care-foundation-of-st-john-s
# https://www.charityintelligence.ca/charity-details/315-health-partners-international-of-canada
# https://www.charityintelligence.ca/charity-details/555-health-sciences-centre-foundation
# https://www.charityintelligence.ca/charity-details/951-healthpartners-canada
# https://www.charityintelligence.ca/charity-details/622-healthy-minds-canada
# https://www.charityintelligence.ca/charity-details/499-heart-stroke
# https://www.charityintelligence.ca/charity-details/498-heart-and-stroke-foundation-of-new-brunswick
# https://www.charityintelligence.ca/charity-details/602-help-lesotho
# https://www.charityintelligence.ca/charity-details/1052-helpage-canada
# https://www.charityintelligence.ca/charity-details/997-herowork
# https://www.charityintelligence.ca/charity-details/796-historica-canada
# https://www.charityintelligence.ca/charity-details/565-hockey-hall-of-fame
# https://www.charityintelligence.ca/charity-details/804-hockey-helps-the-homeless
# https://www.charityintelligence.ca/charity-details/375-holland-bloorview-kids-rehabilitation-hospital-foundation
# https://www.charityintelligence.ca/charity-details/350-homes-first
# https://www.charityintelligence.ca/charity-details/1078-homes-for-heroes-foundation
# https://www.charityintelligence.ca/charity-details/187-hope-air
# https://www.charityintelligence.ca/charity-details/195-hope-and-healing-international
# https://www.charityintelligence.ca/charity-details/969-hope-for-the-nations
# https://www.charityintelligence.ca/charity-details/83-hope-international-development-agency
# https://www.charityintelligence.ca/charity-details/506-hope-mission
# https://www.charityintelligence.ca/charity-details/152-hospice-dufferin
# https://www.charityintelligence.ca/charity-details/357-hospice-of-greater-saint-john
# https://www.charityintelligence.ca/charity-details/151-hospice-of-waterloo
# https://www.charityintelligence.ca/charity-details/225-hospice-toronto
# https://www.charityintelligence.ca/charity-details/325-hospitals-of-regina-foundation
# https://www.charityintelligence.ca/charity-details/169-human-concern-international
# https://www.charityintelligence.ca/charity-details/387-humanitarian-coalition
# https://www.charityintelligence.ca/charity-details/865-humanity-first-canada
# https://www.charityintelligence.ca/charity-details/374-humber-river-hospital-foundation
# https://www.charityintelligence.ca/charity-details/466-hungry-for-life-international
# https://www.charityintelligence.ca/charity-details/119-huntington-society-of-canada
# https://www.charityintelligence.ca/charity-details/850-icna-canada
# https://www.charityintelligence.ca/charity-details/708-immigrant-and-refugee-community-organization-of-manitoba
# https://www.charityintelligence.ca/charity-details/1092-indian-residential-school-survivor-society
# https://www.charityintelligence.ca/charity-details/609-indspire
# https://www.charityintelligence.ca/charity-details/977-indwell-community-homes
# https://www.charityintelligence.ca/charity-details/150-inn-from-the-cold
# https://www.charityintelligence.ca/charity-details/491-institute-for-advancements-in-mental-health
# https://www.charityintelligence.ca/charity-details/298-inter-pares
# https://www.charityintelligence.ca/charity-details/941-inter-varsity-christian-fellowship-of-canada
# https://www.charityintelligence.ca/charity-details/933-interfaith-food-bank-society-of-lethbridge
# https://www.charityintelligence.ca/charity-details/976-international-conservation-fund-of-canada
# https://www.charityintelligence.ca/charity-details/328-international-development-and-relief-foundation
# https://www.charityintelligence.ca/charity-details/454-international-fellowship-of-christians-and-jews-of-canada
# https://www.charityintelligence.ca/charity-details/823-international-justice-mission-canada
# https://www.charityintelligence.ca/charity-details/914-international-teams-canada
# https://www.charityintelligence.ca/charity-details/436-interval-house
# https://www.charityintelligence.ca/charity-details/501-islamic-relief-canada
# https://www.charityintelligence.ca/charity-details/413-iwk-health-centre-foundation
# https://www.charityintelligence.ca/charity-details/896-jack-org
# https://www.charityintelligence.ca/charity-details/281-jane-goodall-institute
# https://www.charityintelligence.ca/charity-details/358-janeway-children-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/619-jays-care-foundation
# https://www.charityintelligence.ca/charity-details/590-jessie-s-the-june-callwood-centre-for-young-women
# https://www.charityintelligence.ca/charity-details/248-jewish-federation-of-greater-vancouver
# https://www.charityintelligence.ca/charity-details/564-jewish-federation-of-winnipeg
# https://www.charityintelligence.ca/charity-details/9-jewish-foundation-of-greater-toronto
# https://www.charityintelligence.ca/charity-details/92-jewish-general-hospital-foundation
# https://www.charityintelligence.ca/charity-details/1050-jewish-heritage-foundation-of-canada
# https://www.charityintelligence.ca/charity-details/570-jewish-national-fund-of-canada
# https://www.charityintelligence.ca/charity-details/418-jim-pattison-children-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/782-joseph-brant-hospital-foundation
# https://www.charityintelligence.ca/charity-details/148-jump-math
# https://www.charityintelligence.ca/charity-details/761-junior-achievement-of-british-columbia
# https://www.charityintelligence.ca/charity-details/758-junior-achievement-of-canada
# https://www.charityintelligence.ca/charity-details/760-junior-achievement-of-central-ontario
# https://www.charityintelligence.ca/charity-details/759-junior-achievement-of-southern-alberta
# https://www.charityintelligence.ca/charity-details/88-juvenile-diabetes-research-foundation-canada
# https://www.charityintelligence.ca/charity-details/962-kamloops-food-bank
# https://www.charityintelligence.ca/charity-details/635-kawartha-food-share
# https://www.charityintelligence.ca/charity-details/634-kayla-s-children-centre
# https://www.charityintelligence.ca/charity-details/802-kelowna-general-hospital-foundation
# https://www.charityintelligence.ca/charity-details/349-kennedy-house-youth-services
# https://www.charityintelligence.ca/charity-details/112-kensington-foundation
# https://www.charityintelligence.ca/charity-details/1034-kerby-centre
# https://www.charityintelligence.ca/charity-details/93-kidney-foundation-of-canada
# https://www.charityintelligence.ca/charity-details/334-kids-cancer-care-foundation-of-alberta
# https://www.charityintelligence.ca/charity-details/179-kids-help-phone
# https://www.charityintelligence.ca/charity-details/256-kids-now
# https://www.charityintelligence.ca/charity-details/660-kidsport-calgary
# https://www.charityintelligence.ca/charity-details/420-kinsmen-foundation
# https://www.charityintelligence.ca/charity-details/814-knowledge-network
# https://www.charityintelligence.ca/charity-details/894-l-arche-canada-foundation
# https://www.charityintelligence.ca/charity-details/1026-lakeridge-health-foundation
# https://www.charityintelligence.ca/charity-details/1098-le-phare-the-lighthouse
# https://www.charityintelligence.ca/charity-details/223-learning-enrichment-foundation
# https://www.charityintelligence.ca/charity-details/666-learning-partnership
# https://www.charityintelligence.ca/charity-details/260-leprosy-relief-canada
# https://www.charityintelligence.ca/charity-details/426-les-grands-ballets-canadiens-de-montreal
# https://www.charityintelligence.ca/charity-details/430-leucan
# https://www.charityintelligence.ca/charity-details/94-leukemia-lymphoma-society-of-canada
# https://www.charityintelligence.ca/charity-details/1054-liberty-for-youth
# https://www.charityintelligence.ca/charity-details/385-life-outreach-international
# https://www.charityintelligence.ca/charity-details/889-lifewater-canada
# https://www.charityintelligence.ca/charity-details/1019-link-charity-canada-inc
# https://www.charityintelligence.ca/charity-details/422-lions-foundation-of-canada-dog-guides
# https://www.charityintelligence.ca/charity-details/311-lions-gate-hospital-foundation
# https://www.charityintelligence.ca/charity-details/535-little-warriors
# https://www.charityintelligence.ca/charity-details/901-livedifferent
# https://www.charityintelligence.ca/charity-details/416-lloydminster-region-health-foundation
# https://www.charityintelligence.ca/charity-details/1059-loeys-dietz-syndrome-foundation-canada
# https://www.charityintelligence.ca/charity-details/1093-loft-community-services
# https://www.charityintelligence.ca/charity-details/922-london-food-bank
# https://www.charityintelligence.ca/charity-details/102-london-health-sciences-foundation
# https://www.charityintelligence.ca/charity-details/982-look-good-feel-better
# https://www.charityintelligence.ca/charity-details/730-loran-scholars-foundation
# https://www.charityintelligence.ca/charity-details/431-lung-association-of-saskatchewan
# https://www.charityintelligence.ca/charity-details/432-lung-health-foundation
# https://www.charityintelligence.ca/charity-details/592-lymphoma-canada
# https://www.charityintelligence.ca/charity-details/813-mackenzie-health-foundation
# https://www.charityintelligence.ca/charity-details/762-mada-community-center
# https://www.charityintelligence.ca/charity-details/178-madd-canada
# https://www.charityintelligence.ca/charity-details/1051-maharam-tav-fund
# https://www.charityintelligence.ca/charity-details/547-make-a-wish-canada
# https://www.charityintelligence.ca/charity-details/65-makeway
# https://www.charityintelligence.ca/charity-details/577-manitoba-possible
# https://www.charityintelligence.ca/charity-details/267-march-of-dimes-canada
# https://www.charityintelligence.ca/charity-details/402-markham-stouffville-hospital-foundation
# https://www.charityintelligence.ca/charity-details/503-mars-discovery-district
# https://www.charityintelligence.ca/charity-details/224-matthews-house-hospice
# https://www.charityintelligence.ca/charity-details/650-mazon-canada
# https://www.charityintelligence.ca/charity-details/95-mcgill-university
# https://www.charityintelligence.ca/charity-details/465-mcgill-university-health-centre-foundation
# https://www.charityintelligence.ca/charity-details/96-mcmaster-university
# https://www.charityintelligence.ca/charity-details/936-meda
# https://www.charityintelligence.ca/charity-details/1014-medicalert-foundation-canada
# https://www.charityintelligence.ca/charity-details/1069-melanoma-canada
# https://www.charityintelligence.ca/charity-details/441-memorial-university-of-newfoundland
# https://www.charityintelligence.ca/charity-details/818-mennonite-central-committee-british-columbia
# https://www.charityintelligence.ca/charity-details/400-mennonite-central-committee-canada
# https://www.charityintelligence.ca/charity-details/440-mennonite-central-committee-manitoba
# https://www.charityintelligence.ca/charity-details/448-mennonite-central-committee-ontario
# https://www.charityintelligence.ca/charity-details/771-mercy-ships-canada
# https://www.charityintelligence.ca/charity-details/1031-merit-award
# https://www.charityintelligence.ca/charity-details/396-michael-garron-hospital-foundation
# https://www.charityintelligence.ca/charity-details/779-michael-j-fox-foundation
# https://www.charityintelligence.ca/charity-details/898-milton-district-hospital-foundation
# https://www.charityintelligence.ca/charity-details/781-mission-aviation-fellowship-of-canada
# https://www.charityintelligence.ca/charity-details/584-mission-inclusion
# https://www.charityintelligence.ca/charity-details/867-mission-inclusion-cardinal-leger-et-ses-oeuvres
# https://www.charityintelligence.ca/charity-details/780-mission-old-brewery
# https://www.charityintelligence.ca/charity-details/795-mission-services-of-hamilton
# https://www.charityintelligence.ca/charity-details/842-mission-services-of-london
# https://www.charityintelligence.ca/charity-details/618-mlse-foundation
# https://www.charityintelligence.ca/charity-details/954-moisson-mauricie-centre-du-quebec
# https://www.charityintelligence.ca/charity-details/766-moisson-montreal
# https://www.charityintelligence.ca/charity-details/952-moisson-quebec
# https://www.charityintelligence.ca/charity-details/146-momentum-community-economic-development-society
# https://www.charityintelligence.ca/charity-details/864-montreal-canadiens-children-s-foundation
# https://www.charityintelligence.ca/charity-details/97-montreal-children-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/98-montreal-general-hospital-foundation
# https://www.charityintelligence.ca/charity-details/492-montreal-heart-institute-foundation
# https://www.charityintelligence.ca/charity-details/326-montreal-museum-of-fine-arts
# https://www.charityintelligence.ca/charity-details/295-montreal-sacre-coeur-hospital-foundation
# https://www.charityintelligence.ca/charity-details/393-montreal-spca
# https://www.charityintelligence.ca/charity-details/168-moorelands-community-services
# https://www.charityintelligence.ca/charity-details/724-mother-teresa-middle-school
# https://www.charityintelligence.ca/charity-details/388-movember-canada
# https://www.charityintelligence.ca/charity-details/905-msc-canada
# https://www.charityintelligence.ca/charity-details/101-multiple-sclerosis-society-of-canada
# https://www.charityintelligence.ca/charity-details/384-multiple-sclerosis-society-of-canada-quebec-division
# https://www.charityintelligence.ca/charity-details/871-multiply
# https://www.charityintelligence.ca/charity-details/464-murchison-foundation
# https://www.charityintelligence.ca/charity-details/467-muscular-dystrophy-canada
# https://www.charityintelligence.ca/charity-details/988-muslim-association-of-canada
# https://www.charityintelligence.ca/charity-details/1090-muslim-welfare-canada
# https://www.charityintelligence.ca/charity-details/944-mustard-seed-street-church
# https://www.charityintelligence.ca/charity-details/764-nankind
# https://www.charityintelligence.ca/charity-details/579-national-arts-centre-foundation
# https://www.charityintelligence.ca/charity-details/408-national-ballet-of-canada
# https://www.charityintelligence.ca/charity-details/1040-national-music-centre
# https://www.charityintelligence.ca/charity-details/695-national-service-dogs
# https://www.charityintelligence.ca/charity-details/991-national-spiritual-assembly-of-the-baha-is-of-canada
# https://www.charityintelligence.ca/charity-details/282-nature-canada
# https://www.charityintelligence.ca/charity-details/37-nature-conservancy-of-canada
# https://www.charityintelligence.ca/charity-details/523-nature-trust-of-british-columbia
# https://www.charityintelligence.ca/charity-details/966-nellie-s
# https://www.charityintelligence.ca/charity-details/109-new-circles-community-services
# https://www.charityintelligence.ca/charity-details/1083-niagara-health-foundation
# https://www.charityintelligence.ca/charity-details/394-north-york-general-hospital-foundation
# https://www.charityintelligence.ca/charity-details/838-north-york-harvest-food-bank
# https://www.charityintelligence.ca/charity-details/1044-northview-community-church
# https://www.charityintelligence.ca/charity-details/284-nova-scotia-nature-trust
# https://www.charityintelligence.ca/charity-details/214-nova-scotia-spca
# https://www.charityintelligence.ca/charity-details/461-nwt-spca
# https://www.charityintelligence.ca/charity-details/395-oakville-hospital-foundation
# https://www.charityintelligence.ca/charity-details/957-ocean-wise-conservation-association
# https://www.charityintelligence.ca/charity-details/438-one-drop-foundation
# https://www.charityintelligence.ca/charity-details/481-ontario-federation-for-cerebral-palsy
# https://www.charityintelligence.ca/charity-details/567-ontario-federation-of-anglers-and-hunters
# https://www.charityintelligence.ca/charity-details/285-ontario-nature
# https://www.charityintelligence.ca/charity-details/41-ontario-society-for-the-prevention-of-cruelty-to-animals
# https://www.charityintelligence.ca/charity-details/210-onward-homes
# https://www.charityintelligence.ca/charity-details/203-opera-atelier
# https://www.charityintelligence.ca/charity-details/419-operation-enfant-soleil
# https://www.charityintelligence.ca/charity-details/120-operation-eyesight-universal
# https://www.charityintelligence.ca/charity-details/604-operation-smile-canada
# https://www.charityintelligence.ca/charity-details/497-opportunity-international-canada
# https://www.charityintelligence.ca/charity-details/840-oratoire-saint-joseph-du-mont-royal
# https://www.charityintelligence.ca/charity-details/405-orbis-canada
# https://www.charityintelligence.ca/charity-details/537-orchestre-symphonique-de-montreal
# https://www.charityintelligence.ca/charity-details/494-orchestre-symphonique-de-quebec
# https://www.charityintelligence.ca/charity-details/297-osteoporosis-canada
# https://www.charityintelligence.ca/charity-details/145-ottawa-food-bank
# https://www.charityintelligence.ca/charity-details/49-ottawa-hospital-foundation
# https://www.charityintelligence.ca/charity-details/218-ottawa-humane-society
# https://www.charityintelligence.ca/charity-details/853-ottawa-mission
# https://www.charityintelligence.ca/charity-details/487-ottawa-regional-cancer-foundation
# https://www.charityintelligence.ca/charity-details/1023-ottawa-gatineau-youth-foundation
# https://www.charityintelligence.ca/charity-details/939-our-daily-bread
# https://www.charityintelligence.ca/charity-details/815-our-place
# https://www.charityintelligence.ca/charity-details/241-ovarian-cancer-canada
# https://www.charityintelligence.ca/charity-details/197-oxfam-canada
# https://www.charityintelligence.ca/charity-details/368-oxfam-quebec
# https://www.charityintelligence.ca/charity-details/704-pacific-assistance-dogs-society
# https://www.charityintelligence.ca/charity-details/286-pacific-salmon-foundation
# https://www.charityintelligence.ca/charity-details/364-pancreatic-cancer-canada
# https://www.charityintelligence.ca/charity-details/1005-parkdale-queen-west-community-health-centre
# https://www.charityintelligence.ca/charity-details/435-parkinson-canada
# https://www.charityintelligence.ca/charity-details/1032-partners-in-health-canada
# https://www.charityintelligence.ca/charity-details/234-partners-in-mission-food-bank
# https://www.charityintelligence.ca/charity-details/144-pathways-clubhouse
# https://www.charityintelligence.ca/charity-details/111-pathways-to-education
# https://www.charityintelligence.ca/charity-details/414-peace-arch-hospital-foundation
# https://www.charityintelligence.ca/charity-details/1053-penny-appeal-canada
# https://www.charityintelligence.ca/charity-details/52-pentecostal-assemblies-of-canada
# https://www.charityintelligence.ca/charity-details/928-peoples-ministries
# https://www.charityintelligence.ca/charity-details/909-peterborough-regional-health-centre-foundation
# https://www.charityintelligence.ca/charity-details/191-pine-river-institute
# https://www.charityintelligence.ca/charity-details/53-plan-international-canada
# https://www.charityintelligence.ca/charity-details/287-pollution-probe-foundation
# https://www.charityintelligence.ca/charity-details/875-portage-foundation
# https://www.charityintelligence.ca/charity-details/710-potential-place-society
# https://www.charityintelligence.ca/charity-details/54-power-to-change
# https://www.charityintelligence.ca/charity-details/245-praxis-spinal-cord-institute
# https://www.charityintelligence.ca/charity-details/1038-presbyterian-world-service-and-development
# https://www.charityintelligence.ca/charity-details/502-president-s-choice-children-s-charity
# https://www.charityintelligence.ca/charity-details/331-primate-s-world-relief-and-development-fund
# https://www.charityintelligence.ca/charity-details/513-prince-county-hospital-foundation
# https://www.charityintelligence.ca/charity-details/55-princess-margaret-cancer-foundation
# https://www.charityintelligence.ca/charity-details/773-progress-place
# https://www.charityintelligence.ca/charity-details/124-prostate-cancer-canada
# https://www.charityintelligence.ca/charity-details/719-prostate-cancer-fight-foundation
# https://www.charityintelligence.ca/charity-details/645-qeii-health-sciences-centre-foundation
# https://www.charityintelligence.ca/charity-details/612-quebec-breast-cancer-foundation
# https://www.charityintelligence.ca/charity-details/517-queen-elizabeth-hospital-foundation
# https://www.charityintelligence.ca/charity-details/56-queen-s-university
# https://www.charityintelligence.ca/charity-details/397-queensway-carleton-hospital-foundation
# https://www.charityintelligence.ca/charity-details/892-quest-food-exchange
# https://www.charityintelligence.ca/charity-details/1006-rainbow-railroad
# https://www.charityintelligence.ca/charity-details/237-raincity-housing
# https://www.charityintelligence.ca/charity-details/934-raising-the-roof
# https://www.charityintelligence.ca/charity-details/1041-ratanak-international
# https://www.charityintelligence.ca/charity-details/1096-raven-respecting-aboriginal-values-and-environmental-needs
# https://www.charityintelligence.ca/charity-details/950-red-deer-food-bank
# https://www.charityintelligence.ca/charity-details/213-red-deer-hospice
# https://www.charityintelligence.ca/charity-details/519-red-deer-regional-health-foundation
# https://www.charityintelligence.ca/charity-details/143-red-door-family-shelter
# https://www.charityintelligence.ca/charity-details/925-regina-district-food-bank
# https://www.charityintelligence.ca/charity-details/121-regional-food-distribution-association
# https://www.charityintelligence.ca/charity-details/589-renascent
# https://www.charityintelligence.ca/charity-details/174-reset-society-of-calgary
# https://www.charityintelligence.ca/charity-details/958-rethink-breast-cancer
# https://www.charityintelligence.ca/charity-details/943-richmond-hill-christian-community-church
# ...
# https://www.charityintelligence.ca/charity-details/348-sketch
# https://www.charityintelligence.ca/charity-details/181-sleeping-children-around-the-world
# https://www.charityintelligence.ca/charity-details/196-smile-train-canada
# https://www.charityintelligence.ca/charity-details/198-sos-children-s-villages-canada
# https://www.charityintelligence.ca/charity-details/202-soulpepper-theatre-company
# https://www.charityintelligence.ca/charity-details/1017-south-okanagan-similkameen-medical-foundation
# https://www.charityintelligence.ca/charity-details/931-southern-alberta-institute-of-technology
# https://www.charityintelligence.ca/charity-details/290-southern-alberta-land-trust-society
# https://www.charityintelligence.ca/charity-details/392-southlake-regional-health-centre-foundation
# https://www.charityintelligence.ca/charity-details/923-southland-church
# https://www.charityintelligence.ca/charity-details/709-special-olympics-british-columbia-society
# https://www.charityintelligence.ca/charity-details/868-special-olympics-canada
# https://www.charityintelligence.ca/charity-details/447-special-olympics-ontario-inc
# https://www.charityintelligence.ca/charity-details/356-speroway
# https://www.charityintelligence.ca/charity-details/1064-spirit-north
# https://www.charityintelligence.ca/charity-details/984-springs-church
# https://www.charityintelligence.ca/charity-details/545-st-boniface-hospital-foundation
# https://www.charityintelligence.ca/charity-details/805-st-joseph-s-health-care-foundation-of-london
# https://www.charityintelligence.ca/charity-details/117-st-joseph-s-health-centre-foundation-of-toronto
# https://www.charityintelligence.ca/charity-details/829-st-joseph-s-healthcare-foundation-hamilton
# https://www.charityintelligence.ca/charity-details/452-st-mary-s-general-hospital-foundation
# https://www.charityintelligence.ca/charity-details/63-st-michael-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/252-st-paul-s-foundation-of-vancouver
# https://www.charityintelligence.ca/charity-details/778-stand-up-to-cancer-canada
# https://www.charityintelligence.ca/charity-details/549-starlight-children-s-foundation
# https://www.charityintelligence.ca/charity-details/940-stella-s-place
# https://www.charityintelligence.ca/charity-details/180-stephen-lewis-foundation
# https://www.charityintelligence.ca/charity-details/993-stepstones-for-youth
# https://www.charityintelligence.ca/charity-details/525-stollery-children-s-hospital-foundation
# https://www.charityintelligence.ca/charity-details/206-stratford-festival
# https://www.charityintelligence.ca/charity-details/603-street-haven
# https://www.charityintelligence.ca/charity-details/878-street-health
# https://www.charityintelligence.ca/charity-details/586-streettohome
# https://www.charityintelligence.ca/charity-details/904-sun-youth-jeunesse-au-soleil
# https://www.charityintelligence.ca/charity-details/62-sunnybrook-foundation
# https://www.charityintelligence.ca/charity-details/1013-surrey-food-bank
# https://www.charityintelligence.ca/charity-details/916-surrey-hospital-foundation
# https://www.charityintelligence.ca/charity-details/1105-takingitglobal
# https://www.charityintelligence.ca/charity-details/929-tamarack-recovery-centre
# https://www.charityintelligence.ca/charity-details/490-tb-vets
# https://www.charityintelligence.ca/charity-details/880-tearfund-canada
# https://www.charityintelligence.ca/charity-details/536-teen-challenge-canada
# https://www.charityintelligence.ca/charity-details/410-telus-spark
# https://www.charityintelligence.ca/charity-details/874-terre-sans-frontieres
# https://www.charityintelligence.ca/charity-details/64-terry-fox-foundation
# https://www.charityintelligence.ca/charity-details/1073-the-519
# https://www.charityintelligence.ca/charity-details/1035-the-alex
# https://www.charityintelligence.ca/charity-details/159-the-boundless-school
# https://www.charityintelligence.ca/charity-details/1088-the-call-of-the-poor
# https://www.charityintelligence.ca/charity-details/981-the-compass
# https://www.charityintelligence.ca/charity-details/1030-the-food-bank-of-waterloo-region
# https://www.charityintelligence.ca/charity-details/1062-the-land-conservancy-of-british-columbia
# https://www.charityintelligence.ca/charity-details/913-the-meeting-house-church-family
# https://www.charityintelligence.ca/charity-details/103-the-mustard-seed
# https://www.charityintelligence.ca/charity-details/118-the-neighbourhood-group
# https://www.charityintelligence.ca/charity-details/734-the-redwood
# https://www.charityintelligence.ca/charity-details/648-the-robb-nash-project
# https://www.charityintelligence.ca/charity-details/126-the-stop-community-food-centre
# https://www.charityintelligence.ca/charity-details/1003-thunder-bay-regional-health-sciences-foundation
# https://www.charityintelligence.ca/charity-details/66-tim-hortons-foundation-camps
# https://www.charityintelligence.ca/charity-details/133-toronto-city-mission
# https://www.charityintelligence.ca/charity-details/893-toronto-foundation-for-student-success
# https://www.charityintelligence.ca/charity-details/211-toronto-humane-society
# https://www.charityintelligence.ca/charity-details/336-toronto-international-film-festival
# https://www.charityintelligence.ca/charity-details/698-toronto-kiwanis-boys-girls-clubs
# https://www.charityintelligence.ca/charity-details/980-toronto-metropolitan-university
# https://www.charityintelligence.ca/charity-details/702-toronto-people-with-aids-foundation
# https://www.charityintelligence.ca/charity-details/372-toronto-public-library-foundation
# https://www.charityintelligence.ca/charity-details/947-toronto-rehab-foundation
# https://www.charityintelligence.ca/charity-details/1047-toronto-star-children-s-charities
# https://www.charityintelligence.ca/charity-details/574-toronto-symphony-orchestra
# https://www.charityintelligence.ca/charity-details/291-toronto-wildlife-centre
# https://www.charityintelligence.ca/charity-details/883-trails-youth-initiatives
# https://www.charityintelligence.ca/charity-details/369-trans-canada-trail
# https://www.charityintelligence.ca/charity-details/1070-tree-canada
# https://www.charityintelligence.ca/charity-details/1099-trellis-society
# https://www.charityintelligence.ca/charity-details/643-trent-university
# https://www.charityintelligence.ca/charity-details/332-trillium-health-partners-foundation
# https://www.charityintelligence.ca/charity-details/292-trout-unlimited-canada
# https://www.charityintelligence.ca/charity-details/1068-true-north-aid
# https://www.charityintelligence.ca/charity-details/530-true-north-youth-foundation
# https://www.charityintelligence.ca/charity-details/566-true-patriot-love-foundation
# https://www.charityintelligence.ca/charity-details/449-tvontario-tvo
# https://www.charityintelligence.ca/charity-details/257-uforchange
# https://www.charityintelligence.ca/charity-details/15-uhn-foundation
# https://www.charityintelligence.ca/charity-details/1011-unhcr-canada
# https://www.charityintelligence.ca/charity-details/16-unicef-canada
# https://www.charityintelligence.ca/charity-details/246-union-gospel-mission
# https://www.charityintelligence.ca/charity-details/935-united-church-of-canada
# https://www.charityintelligence.ca/charity-details/17-united-israel-appeal-of-canada
# https://www.charityintelligence.ca/charity-details/18-united-jewish-appeal-of-greater-toronto
# https://www.charityintelligence.ca/charity-details/1060-united-way-british-columbia
# https://www.charityintelligence.ca/charity-details/22-united-way-east-ontario
# https://www.charityintelligence.ca/charity-details/321-united-way-elgin-middlesex
# https://www.charityintelligence.ca/charity-details/20-united-way-greater-toronto
# https://www.charityintelligence.ca/charity-details/320-united-way-halifax
# https://www.charityintelligence.ca/charity-details/887-united-way-halton-hamilton
# https://www.charityintelligence.ca/charity-details/30-united-way-of-alberta-capital-region
# https://www.charityintelligence.ca/charity-details/28-united-way-of-calgary-and-area
# https://www.charityintelligence.ca/charity-details/324-united-way-of-fort-mcmurray
# https://www.charityintelligence.ca/charity-details/439-united-way-of-greater-moncton-and-southeastern-new-brunswick-region
# https://www.charityintelligence.ca/charity-details/637-united-way-of-kingston-frontenac-lennox-and-addington
# https://www.charityintelligence.ca/charity-details/362-united-way-of-regina
# https://www.charityintelligence.ca/charity-details/318-united-way-of-saskatoon-area
# https://www.charityintelligence.ca/charity-details/27-united-way-of-the-lower-mainland
# https://www.charityintelligence.ca/charity-details/427-united-way-saint-john-kings-and-charlotte
# https://www.charityintelligence.ca/charity-details/811-united-way-southern-vancouver-island
# https://www.charityintelligence.ca/charity-details/451-united-way-waterloo-region-communities
# https://www.charityintelligence.ca/charity-details/35-united-way-winnipeg
# https://www.charityintelligence.ca/charity-details/391-united-way-centraide-windsor-essex-county
# https://www.charityintelligence.ca/charity-details/220-unity-charity
# https://www.charityintelligence.ca/charity-details/846-universite-de-montreal
# https://www.charityintelligence.ca/charity-details/425-university-hospital-foundation
# https://www.charityintelligence.ca/charity-details/412-university-hospitals-kingston-foundation
# https://www.charityintelligence.ca/charity-details/39-university-of-alberta
# https://www.charityintelligence.ca/charity-details/43-university-of-british-columbia
# https://www.charityintelligence.ca/charity-details/44-university-of-calgary
# https://www.charityintelligence.ca/charity-details/47-university-of-guelph
# https://www.charityintelligence.ca/charity-details/46-university-of-manitoba
# https://www.charityintelligence.ca/charity-details/453-university-of-new-brunswick
# https://www.charityintelligence.ca/charity-details/48-university-of-ottawa
# https://www.charityintelligence.ca/charity-details/507-university-of-ottawa-heart-institute-foundation
# https://www.charityintelligence.ca/charity-details/409-university-of-prince-edward-island
# https://www.charityintelligence.ca/charity-details/306-university-of-regina
# https://www.charityintelligence.ca/charity-details/50-university-of-saskatchewan
# https://www.charityintelligence.ca/charity-details/51-university-of-toronto
# https://www.charityintelligence.ca/charity-details/249-university-of-victoria
# https://www.charityintelligence.ca/charity-details/848-university-of-waterloo
# https://www.charityintelligence.ca/charity-details/24-university-of-western-ontario
# https://www.charityintelligence.ca/charity-details/985-vancouver-art-gallery
# https://www.charityintelligence.ca/charity-details/310-vancouver-opera-association
# https://www.charityintelligence.ca/charity-details/554-vancouver-symphony-orchestra
# https://www.charityintelligence.ca/charity-details/526-variety-bc
# https://www.charityintelligence.ca/charity-details/839-ve-ahavta
# https://www.charityintelligence.ca/charity-details/1024-veterans-transition-network
# https://www.charityintelligence.ca/charity-details/1079-vets-canada
# https://www.charityintelligence.ca/charity-details/1081-vets-without-borders
# https://www.charityintelligence.ca/charity-details/32-vgh-and-ubc-hospital-foundation
# https://www.charityintelligence.ca/charity-details/1082-victoria-cool-aid-society
# https://www.charityintelligence.ca/charity-details/137-victoria-hospice-society
# https://www.charityintelligence.ca/charity-details/312-victoria-hospitals-foundation
# https://www.charityintelligence.ca/charity-details/806-visions-of-science
# https://www.charityintelligence.ca/charity-details/508-vocm-cares
# https://www.charityintelligence.ca/charity-details/38-war-amps
# https://www.charityintelligence.ca/charity-details/265-war-child-canada
# https://www.charityintelligence.ca/charity-details/40-watch-tower-bible-and-tract-society-of-canada
# https://www.charityintelligence.ca/charity-details/1029-water-first
# https://www.charityintelligence.ca/charity-details/687-wateraid-canada
# https://www.charityintelligence.ca/charity-details/786-watoto-canada
# https://www.charityintelligence.ca/charity-details/1001-wavaw-rape-crisis-centre
# https://www.charityintelligence.ca/charity-details/1046-wcpd-foundation
# https://www.charityintelligence.ca/charity-details/82-we-charity
# https://www.charityintelligence.ca/charity-details/1103-we-charity-foundation
# https://www.charityintelligence.ca/charity-details/307-welcome-hall-mission
# https://www.charityintelligence.ca/charity-details/907-wellspring-alberta
# https://www.charityintelligence.ca/charity-details/355-wellspring-cancer-support-foundation
# https://www.charityintelligence.ca/charity-details/836-wesley
# https://www.charityintelligence.ca/charity-details/816-west-park-foundation
# https://www.charityintelligence.ca/charity-details/193-weston-king-neighbourhood-centre
# https://www.charityintelligence.ca/charity-details/294-wilderness-committee
# https://www.charityintelligence.ca/charity-details/293-wildlife-conservation-society-canada
# https://www.charityintelligence.ca/charity-details/296-wildlife-preservation-canada
# https://www.charityintelligence.ca/charity-details/407-wilfrid-laurier-university
# https://www.charityintelligence.ca/charity-details/552-william-osler-health-system-foundation
# https://www.charityintelligence.ca/charity-details/443-winnipeg-humane-society
# https://www.charityintelligence.ca/charity-details/1066-wish-drop-in-centre-society
# https://www.charityintelligence.ca/charity-details/445-women-in-need-society-of-calgary
# https://www.charityintelligence.ca/charity-details/382-women-s-centre-of-york-region
# https://www.charityintelligence.ca/charity-details/437-women-s-college-hospital-foundation
# https://www.charityintelligence.ca/charity-details/580-woodgreen-community-services
# https://www.charityintelligence.ca/charity-details/367-world-animal-protection
# https://www.charityintelligence.ca/charity-details/942-world-federation-of-hemophilia
# https://www.charityintelligence.ca/charity-details/607-world-renew
# https://www.charityintelligence.ca/charity-details/376-world-university-service-of-canada
# https://www.charityintelligence.ca/charity-details/33-world-vision-canada
# https://www.charityintelligence.ca/charity-details/36-world-wildlife-fund
# https://www.charityintelligence.ca/charity-details/793-wounded-warriors-canada
# https://www.charityintelligence.ca/charity-details/42-wycliffe
# https://www.charityintelligence.ca/charity-details/236-yellow-brick-house
# https://www.charityintelligence.ca/charity-details/129-ymca-of-greater-toronto
# https://www.charityintelligence.ca/charity-details/588-ymca-of-greater-vancouver
# https://www.charityintelligence.ca/charity-details/190-yonge-street-mission
# https://www.charityintelligence.ca/charity-details/406-york-university
# https://www.charityintelligence.ca/charity-details/965-yorktown-family-services
# https://www.charityintelligence.ca/charity-details/462-young-adult-cancer-canada
# https://www.charityintelligence.ca/charity-details/851-young-life-of-canada
# https://www.charityintelligence.ca/charity-details/128-youth-employment-services
# https://www.charityintelligence.ca/charity-details/613-youth-empowerment-and-support-services
# https://www.charityintelligence.ca/charity-details/222-youth-fusion-fusion-jeunesse
# https://www.charityintelligence.ca/charity-details/706-youth-unlimited
# https://www.charityintelligence.ca/charity-details/986-youth-with-a-mission-bc-society
# https://www.charityintelligence.ca/charity-details/141-youth-without-shelter
# https://www.charityintelligence.ca/charity-details/921-youthlink
# https://www.charityintelligence.ca/charity-details/527-yukon-hospital-foundation
# https://www.charityintelligence.ca/charity-details/323-ywca-calgary
# https://www.charityintelligence.ca/charity-details/489-ywca-metro-vancouver
# https://www.charityintelligence.ca/charity-details/524-ywca-nwt
# https://www.charityintelligence.ca/charity-details/539-ywca-toronto
# https://www.charityintelligence.ca/charity-details/1025-zichron-chaim-charity

# %% [markdown]
# ## Paso 4: Investigar nuevamente las páginas

# %% [markdown]
# ![Revisar código de cada elemento](./images/devtools_02.png "Revisar código de cada elemento")

# %% [markdown]
# ## Paso 5: Solicitud a Chat GPT con una liga de prueba

# %% [markdown]
# Primero le doy el código que ya llevo (esto porque lo hice en un día diferente yes para darle contexto):
# ![chatGPT](./images/prompt_04.png "pregunta a chatGPT")
# Luego le digo lo que necesito:
# ![chatGPT](./images/prompt_05.png "pregunta a chatGPT")
# Luego copio el código y lo voy corrigiendo y complementando:
# ![chatGPT](./images/prompt_06.png "pregunta a chatGPT")

# %%
##############################################################################################################
######################## Éste es mi código sucio, lo deje como ejemplo #####################################
#############################################################################################################

# # Define the function to scrape details from the first charity link
# def scrape_charity_details(url):
#     response = requests.get(url)
#     if response.status_code != 200:
#         print(f"Failed to retrieve charity page {url}")
#         return {}

#     soup = BeautifulSoup(response.content, 'html.parser')
#     charity_details = {}

#     # Extract the required fields
#     charity_details['charity'] = soup.find('h1', class_='sppb-addon-title').get_text(strip=True)
#     # charity_type = soup.find('div', id='sppb-addon-1551725103589').get_text(strip=True)
#     # print(charity_type)

#     # Find the div with the specific id
#     addon_div = soup.find('div', id='sppb-addon-1551725103589')

#     # Extract the text from the <a> tags
#     links = addon_div.find_all('a')

#     # Extract the text for each <a> tag
#     charity_details['type']  = links[0].get_text(strip=True)
#     charity_details['status']  = links[1].get_text(strip=True)

#     # Extract address and Charitable Registration
#     address_section = soup.find('div', id="column-wrap-id-1548969998232")
#     if address_section:
#         address_content = address_section.find('div', class_='sppb-addon-content').get_text(separator='\n').split('\n')
#         charity_details['address'] = ' '.join(address_content[:3]).strip()
#         charity_details['Charitable Registration'] = address_content[-1].strip().split(':')[-1].strip()

#     charity_details['stars'] = soup.find('span', class_='rating_stars').get('title').split(':')[-1].strip()
#     charity_details['FINANCIAL TRANSPARENCY_1'] = soup.find('p', style="font-weight: bolder;font-size: 35px;", align="center").get_text(strip=True)
#     charity_details['FINANCIAL TRANSPARENCY_2'] = soup.find('p', style="font-size: 12px;").get_text(strip=True)
#     charity_details['RESULTS REPORTING_1'] = soup.find('p', style="font-family: 'Source Sans Pro', sans-serif;;font-weight: bolder;align='center';font-size: 35px; color:rgb(192,0,0)").get_text(strip=True)
#     charity_details['RESULTS REPORTING_2'] = soup.find('p', style="font-size: 12px;").get_text(strip=True)
#     charity_details['DEMONSTRATED IMPACT_1'] = soup.find('p', style="font-family: 'Source Sans Pro', sans-serif;font-weight: bolder;align='center';font-size: 35px;").get_text(strip=True)
#     charity_details['DEMONSTRATED IMPACT_2'] = soup.find('p', style="font-size: 12px;").get_text(strip=True)
# ###### FALTA EL SVG #####
#     charity_details['NEED FOR FUNDING'] = soup.find('p', style="font-size: 12px;").get_text(strip=True)
#     charity_details['CENTS TO THE CAUSE_1'] = soup.find('p', style="font-family: 'Source Sans Pro', sans-serif;font-weight: bolder;align='center';font-size: 35px;").get_text(strip=True)
#     charity_details['CENTS TO THE CAUSE_2'] = soup.find('p', style="font-size: 12px;").get_text(strip=True)
#     overview = soup.find('div', id="sppb-addon-1549915418046").find_all('p')
#     charity_details['OVERVIEW'] = ' '.join([p.get_text(strip=True) for p in overview])
#     results_impact = soup.find('div', id='sppb-addon-1549916615776').find_all('p')
#     # print(results_impact)
#     charity_details['RESULTS AND IMPACT'] = ' '.join([p.get_text(strip=True) for p in results_impact])
#     finances = soup.find('div', id='column-wrap-id-1551726899554').find_all('p')
#     charity_details['FINANCES'] = ' '.join([p.get_text(strip=True) for p in finances])
#     # print(finances)
#     salary = soup.find('div', id='sppb-addon-1549916615773').find_all('p')
#     # charity_details['Salary Information'] = ' '.join([p.get_text(strip=True) for p in salary])
#     charity_details['Full-time staff']  = salary[0].find('span').get_text(strip=True) if len(salary) > 0 else ''
#     charity_details['Avg. compensation']  = salary[1].find('span').get_text(strip=True) if len(salary) > 1 else ''
#     # print(salary)

#     # Find the div containing the tables
#     stats_div = soup.find('div', id='stats')
    
#     # Extract the first table with class 'stats_table ratios'
#     table1 = stats_div.find('table', class_='stats_table ratios')
#     # print(table1)

#     # Extract the headers and data from the Financial Ratios table
#     headers1 = [th.get_text(strip=True) for th in table1.find_all('th')]
#     rows1 = table1.find_all('tr')[1:]  # Skip the header row
#     # print(headers1,rows1)
# ##############################
#     data1 = []
#     for row in rows1:
#         cols = row.find_all('td')
#         data_row = [col.get_text(strip=True) for col in cols]
#         data1.append(data_row)
#     # print(data1)
#     # print(data1[0][0] + " (" + headers1[0] +")")

#     for j in range(len(data1[0])):
#         # print(data1[j][0])
#         for i in range(len(headers1)):
#             # print(headers1[i])
#             # print(data1[j][0] + " (" + headers1[i] +")")
#             # print(data1[j][i+1])
#             column_name = data1[j][0] + " (" + headers1[i] +")"
#             # print(column_name)
#             charity_details[column_name] = data1[j][i+1]

#     # Extract the second table with class 'stats_table summary'
#     table2 = stats_div.find('table', class_='stats_table summary')
    
#     # Extract the headers and data from the Summary Financial Statements table
#     headers2 = [th.get_text(strip=True) for th in table2.find_all('th')]
#     rows2 = table2.find_all('tr')[1:]  # Skip the header row
#     # print(rows2)
    
#     data2 = []
#     for row in rows2:
#         cols = row.find_all('td')
#         data_row = [col.get_text(strip=True) for col in cols]
#         data2.append(data_row)
#     # print(data2[5][0])

#     for j in range(len(data2)):
#         # print(data2[j])
#         for i in range(len(headers2)):
#             # print(headers1[i])
#             # print(data1[j][0] + " (" + headers1[i] +")")
#             # print(data1[j][i+1])
#             column_name = data2[j][0] + " (" + headers2[i] +")"
#             # print(column_name)
#             charity_details[column_name] = data2[j][i+1]

#     table3 = soup.find('div', id='sppb-addon-1549916615773').find('table')
#     # print(table3)
    
#     # Initialize lists to hold the data
#     salary_ranges = []
#     counts = []

#     # Iterate over all rows in the table
#     for row in table3.find_all('tr'):
#         cells = row.find_all('td')
#         if len(cells) == 2:  # Ensure the row has the correct number of columns
#             salary_range = cells[0].get_text(strip=True)
#             count = cells[1].get_text(strip=True)
#             charity_details[salary_range] = count
#             salary_ranges.append(salary_range)
#             counts.append(count)
#     # print(salary_ranges, counts)

#     comments = soup.find('div', id='sppb-addon-1549917617861').find_all('p')
#     charity_details['COMMENTS'] = ' '.join([p.get_text(strip=True) for p in comments])
#     # print(comments)

#     # Find the div containing the contact info
#     contact_div = soup.find('div', id='sppb-addon-1549917617869').find('div', class_='sppb-addon-content')

#     # Extract and clean the contact info text
#     contact_info = contact_div.get_text(separator=' ', strip=True)

#     # Print the contact info
#     # print(contact_info)

#     # Split the contact info into parts
#     # Remove the unwanted string "This email address is being protected from spambots. You need JavaScript enabled to view it."
#     contact_info_cleaned = contact_info.replace("This email address is being protected from spambots. You need JavaScript enabled to view it.", "").strip()
#     charity_details['contact'] = contact_info_cleaned 



#     return charity_details

# %%
# # Scrape details for the first charity link
# first_charity_url = all_links[0]
# charity_data = scrape_charity_details(first_charity_url)

# # Create DataFrame
# df = pd.DataFrame([charity_data])

# # Save DataFrame to a CSV file
# df.to_csv('./data/charity_intelligence_details.csv', index=False)

# # Print DataFrame
# df

# %%
# df.columns

# %% [markdown]
# Este es mi codigo final sólo me falto el SVG

# %%
def scrape_charity_details(url):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve charity page {url}")
        return {}

    soup = BeautifulSoup(response.content, 'html.parser')
    charity_details = {}

    # Extract the required fields
    charity_name_tag = soup.find('h1', class_='sppb-addon-title')
    if charity_name_tag:
        charity_details['charity'] = charity_name_tag.get_text(strip=True)

    addon_div = soup.find('div', id='sppb-addon-1551725103589')
    if addon_div:
        links = addon_div.find_all('a')
        if len(links) > 0:
            charity_details['type'] = links[0].get_text(strip=True)
        if len(links) > 1:
            charity_details['status'] = links[1].get_text(strip=True)

    address_section = soup.find('div', id="column-wrap-id-1548969998232")
    if address_section:
        address_content = address_section.find('div', class_='sppb-addon-content').get_text(separator='\n').split('\n')
        if len(address_content) >= 3:
            charity_details['address'] = ' '.join(address_content[:3]).strip()
        if len(address_content) > 0:
            charity_details['Charitable Registration'] = address_content[-1].strip().split(':')[-1].strip()

    rating_tag = soup.find('span', class_='rating_stars')
    if rating_tag:
        charity_details['stars'] = rating_tag.get('title').split(':')[-1].strip()

    financial_transparency_1 = soup.find('p', style="font-weight: bolder;font-size: 35px;", align="center")
    if financial_transparency_1:
        charity_details['FINANCIAL TRANSPARENCY_1'] = financial_transparency_1.get_text(strip=True)

    financial_transparency_2 = soup.find('p', style="font-size: 12px;")
    if financial_transparency_2:
        charity_details['FINANCIAL TRANSPARENCY_2'] = financial_transparency_2.get_text(strip=True)

    results_reporting_1 = soup.find('p', style="font-family: 'Source Sans Pro', sans-serif;;font-weight: bolder;align='center';font-size: 35px; color:rgb(192,0,0)")
    if results_reporting_1:
        charity_details['RESULTS REPORTING_1'] = results_reporting_1.get_text(strip=True)

    results_reporting_2 = soup.find('p', style="font-size: 12px;")
    if results_reporting_2:
        charity_details['RESULTS REPORTING_2'] = results_reporting_2.get_text(strip=True)

    demonstrated_impact_1 = soup.find('p', style="font-family: 'Source Sans Pro', sans-serif;font-weight: bolder;align='center';font-size: 35px;")
    if demonstrated_impact_1:
        charity_details['DEMONSTRATED IMPACT_1'] = demonstrated_impact_1.get_text(strip=True)

    demonstrated_impact_2 = soup.find('p', style="font-size: 12px;")
    if demonstrated_impact_2:
        charity_details['DEMONSTRATED IMPACT_2'] = demonstrated_impact_2.get_text(strip=True)

    need_for_funding = soup.find('p', style="font-size: 12px;")
    if need_for_funding:
        charity_details['NEED FOR FUNDING'] = need_for_funding.get_text(strip=True)

    cents_to_cause_1 = soup.find('p', style="font-family: 'Source Sans Pro', sans-serif;font-weight: bolder;align='center';font-size: 35px;")
    if cents_to_cause_1:
        charity_details['CENTS TO THE CAUSE_1'] = cents_to_cause_1.get_text(strip=True)

    cents_to_cause_2 = soup.find('p', style="font-size: 12px;")
    if cents_to_cause_2:
        charity_details['CENTS TO THE CAUSE_2'] = cents_to_cause_2.get_text(strip=True)

    overview = soup.find('div', id="sppb-addon-1549915418046").find_all('p')
    if overview:
        charity_details['OVERVIEW'] = ' '.join([p.get_text(strip=True) for p in overview])

    results_impact = soup.find('div', id='sppb-addon-1549916615776').find_all('p')
    if results_impact:
        charity_details['RESULTS AND IMPACT'] = ' '.join([p.get_text(strip=True) for p in results_impact])

    finances = soup.find('div', id='column-wrap-id-1551726899554').find_all('p')
    if finances:
        charity_details['FINANCES'] = ' '.join([p.get_text(strip=True) for p in finances])

    salary = soup.find('div', id='sppb-addon-1549916615773').find_all('p')
    if salary:
        charity_details['Full-time staff'] = salary[0].find('span').get_text(strip=True) if len(salary) > 0 else ''
        charity_details['Avg. compensation'] = salary[1].find('span').get_text(strip=True) if len(salary) > 1 else ''

    stats_div = soup.find('div', id='stats')
    if stats_div:
        table1 = stats_div.find('table', class_='stats_table ratios')
        if table1:
            headers1 = [th.get_text(strip=True) for th in table1.find_all('th')]
            rows1 = table1.find_all('tr')[1:]
            data1 = []
            for row in rows1:
                cols = row.find_all('td')
                data_row = [col.get_text(strip=True) for col in cols]
                data1.append(data_row)
            for j in range(len(data1)):
                for i in range(1, len(headers1)):
                    if i < len(data1[j]):
                        column_name = data1[j][0] + " (" + headers1[i] +")"
                        charity_details[column_name] = data1[j][i]

        table2 = stats_div.find('table', class_='stats_table summary')
        if table2:
            headers2 = [th.get_text(strip=True) for th in table2.find_all('th')]
            rows2 = table2.find_all('tr')[1:]
            data2 = []
            for row in rows2:
                cols = row.find_all('td')
                data_row = [col.get_text(strip=True) for col in cols]
                data2.append(data_row)
            for j in range(len(data2)):
                for i in range(1, len(headers2)):
                    if i < len(data2[j]):
                        column_name = data2[j][0] + " (" + headers2[i] +")"
                        charity_details[column_name] = data2[j][i]

    table3 = soup.find('div', id='sppb-addon-1549916615773').find('table')
    if table3:
        salary_ranges = []
        counts = []
        for row in table3.find_all('tr'):
            cells = row.find_all('td')
            if len(cells) == 2:
                salary_range = cells[0].get_text(strip=True)
                count = cells[1].get_text(strip=True)
                charity_details[salary_range] = count
                salary_ranges.append(salary_range)
                counts.append(count)

    comments = soup.find('div', id='sppb-addon-1549917617861').find_all('p')
    if comments:
        charity_details['COMMENTS'] = ' '.join([p.get_text(strip=True) for p in comments])

    contact_div = soup.find('div', id='sppb-addon-1549917617869').find('div', class_='sppb-addon-content')
    if contact_div:
        contact_info = contact_div.get_text(separator=' ', strip=True)
        contact_info_cleaned = contact_info.replace("This email address is being protected from spambots. You need JavaScript enabled to view it.", "").strip()
        charity_details['contact'] = contact_info_cleaned

    return charity_details

# %% [markdown]
# ## Paso 6: Crear un for

# %%
# Initialize a list to hold the data for all charities
all_charity_data = []

# Loop through all links and scrape details for each charity
for link in all_links:
    charity_data = scrape_charity_details(link)
    all_charity_data.append(charity_data)

# Create DataFrame
df = pd.DataFrame(all_charity_data)
# Out:
# Failed to retrieve charity page https://www.charityintelligence.ca/charity-details/257-uforchange

# %%
df
# Out:
#                                       charity  \
# 0                    360Kids Support Services
# 1                       A Better World Canada
# 2                           Acadia University
# 3                              Acclaim Health
# 4    Action Canada for Sexual Health & Rights
# ..                                        ...
# 843                              YWCA Calgary
# 844                      YWCA Metro Vancouver
# 845                                  YWCA NWT
# 846                              YWCA Toronto
# 847                     Zichron Chaim Charity
#
#                                 type             status  \
# 0    Social Services - At-Risk Youth  Operating Charity
# 1                  International Aid  Operating Charity
# 2             Education - University  Operating Charity
# 3                             Health  Operating Charity
# 4                             Health  Operating Charity
# ..                               ...                ...
# 843          Social Services - Women  Operating Charity
# 844          Social Services - Women  Operating Charity
# 845          Social Services - Women  Operating Charity
# 846          Social Services - Women  Operating Charity
# 847                  Social Services  Public Foundation
#
#                                                address  \
# 0    80F Centurian Drive, Suite 200 Markham, ON L3R...
# 1            #206-5033 52nd Street Lacombe, AB T4L 2A6
# 2           15 University Avenue Wolfville, NS B4P 2R6
# 3                2370 Speers Road Oakville, ON L6L 5M2
# 4                   240 Bank Street Ottawa, ON K2P 1X4
# ..                                                 ...
# 843            1715 – 17 Avenue SE Calgary, AB T2G 5J1
# 844            535 Hornby Street Vancouver, BC V6C 2E8
# 845     4904-54 Ave. Suite 104 Yellowknife, NT X1A 1H7
# 846                  87 Elm Street Toronto, ON M5G 0A8
# 847               6288 Ch. Deacon Montreal, QC H3S 2P5
#
#     Charitable Registration stars FINANCIAL TRANSPARENCY_1  \
# 0         89703 6620 RR0001   5/5                       ✔+
# 1         80099 4006 RR0001   2/5                        ✖
# 2         10668 1893 RR0001   3/5                       ✔+
# 3         11928 4602 RR0001   2/5                       ✔+
# 4         10784 8319 RR0001   3/5                        ✖
# ..                      ...   ...                      ...
# 843       10822 7927 RR0001   4/5                       ✔+
# 844       10822 7943 RR0001   2/5                       ✔+
# 845       11930 7411 RR0001   2/5                        ✖
# 846       10822 9865 RR0001   3/5                       ✔+
# 847       73551 1925 RR0001   0/5                        ✖
#
#                               FINANCIAL TRANSPARENCY_2 RESULTS REPORTING_1  \
# 0    Audited financial statementsfor current and pr...                  A-
# 1    Audited financial statementsavailable only thr...                  B+
# 2    Audited financial statementsfor current and pr...                  B-
# 3    Audited financial statementsfor current and pr...                   C
# 4    Audited financial statementsavailable only upo...                  B+
# ..                                                 ...                 ...
# 843  Audited financial statementsfor current and pr...                   B
# 844  Audited financial statementsfor current and pr...                   B
# 845  Audited financial statementsavailable only thr...                  B-
# 846  Audited financial statementsfor current and pr...                  B-
# 847  Audited financial statementsavailable only thr...                   F
#
#                                    RESULTS REPORTING_2  ...  \
# 0    Audited financial statementsfor current and pr...  ...
# 1    Audited financial statementsavailable only thr...  ...
# 2    Audited financial statementsfor current and pr...  ...
# 3    Audited financial statementsfor current and pr...  ...
# 4    Audited financial statementsavailable only upo...  ...
# ..                                                 ...  ...
# 843  Audited financial statementsfor current and pr...  ...
# 844  Audited financial statementsfor current and pr...  ...
# 845  Audited financial statementsavailable only thr...  ...
# 846  Audited financial statementsfor current and pr...  ...
# 847  Audited financial statementsavailable only thr...  ...
#
#     Business activities (net) (2015) Business activities (net) (2014)  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ..                               ...                              ...
# 843                              NaN                              NaN
# 844                              NaN                              NaN
# 845                              NaN                              NaN
# 846                              NaN                              NaN
# 847                              NaN                              NaN
#
#     Special events (2014) Other costs (2015) Investment income (2011)  \
# 0                     NaN                NaN                      NaN
# 1                     NaN                NaN                      NaN
# 2                     NaN                NaN                      NaN
# 3                     NaN                NaN                      NaN
# 4                     NaN                NaN                      NaN
# ..                    ...                ...                      ...
# 843                   NaN                NaN                      NaN
# 844                   NaN                NaN                      NaN
# 845                   NaN                NaN                      NaN
# 846                   NaN                NaN                      NaN
# 847                   NaN                NaN                      NaN
#
#     Other income (2011) Program costs - International (2011)  \
# 0                   NaN                                  NaN
# 1                   NaN                                  NaN
# 2                   NaN                                  NaN
# 3                   NaN                                  NaN
# 4                   NaN                                  NaN
# ..                  ...                                  ...
# 843                 NaN                                  NaN
# 844                 NaN                                  NaN
# 845                 NaN                                  NaN
# 846                 NaN                                  NaN
# 847                 NaN                                  NaN
#
#     Program costs - Canada (2011) Fundraising costs (2011)  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                             NaN                      NaN
# ..                            ...                      ...
# 843                           NaN                      NaN
# 844                           NaN                      NaN
# 845                           NaN                      NaN
# 846                           NaN                      NaN
# 847                           NaN                      NaN
#
#     Donor-designated donations (2023)
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 843                               NaN
# 844                               NaN
# 845                               NaN
# 846                               NaN
# 847                               NaN
#
# [848 rows x 372 columns]

# %% [markdown]
# ## Paso 7: Guardar a un CSV

# %%
# Save DataFrame to a CSV file
df.to_csv('./data/charity_intelligence_details.csv', index=False)
